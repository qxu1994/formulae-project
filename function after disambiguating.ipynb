# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from dataset import get_manchester
from functionword_tagger import FunctionWordTagger
plt.rcParams['figure.figsize'] = 15, 6

# %%
df = pd.read_excel('count ambiguous words.xlsx')
df
# Out:
#    ngram_child  count_child   label_child ngram_mother  count_mother  \
# 0          her          429    possessive          her          2298
# 1          her          270       pronoun          her          1805
# 2         once            4        adverb         once            45
# 3         once            0   conjunction         once            29
# 4         once            0          noun         once            22
# 5       before            0   preposition       before            34
# 6       before            6        adverb       before           131
# 7       before            6   conjunction       before           266
# 8        after           40   preposition        after           271
# 9        after            4        adverb        after            47
# 10       after           14   conjunction        after            96
# 11          'd            4         modal           'd           655
# 12          'd            0     auxiliary           'd           111
# ...

# %%
count = df.groupby('label_child', 'label_mother').agg('count_child', 'count_mother')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7a95f1135843> in <module>()
# ----> 1 count = df.groupby('label_child', 'label_mother').agg('count_child', 'count_mother')
#
# E:\anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4266         if level is None and by is None:
#    4267             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 4268         axis = self._get_axis_number(axis)
#    4269         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4270                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# E:\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     349                 pass
#     350         raise ValueError('No axis named {0} for object type {1}'
# ...
